# %% [markdown]
# #### Import Package & Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

#Data merupakan dummy data dari brand sampo
dfB = pd.read_csv(r"E:\MINE\beasiswa\2022\DATA BANGLORE\ON BOARDING\EXAM + TASK\5 - DATA VISUALIZATION\botak.csv")
dfB
# Out:
#       umur jenis_kelamin       pekerjaan    provinsi          gaji  \
# 0     36.0     Laki-laki             PNS   Palembang  8.072967e+06
# 1     32.0     Perempuan       Freelance    Surabaya  6.632271e+06
# 2     35.0     Laki-laki             PNS        Palu  6.737048e+06
# 3     36.0     Laki-laki  Pegawai swasta   Samarinda  5.252883e+06
# 4     53.0     Laki-laki    Pengangguran       Ambon  8.279310e+06
# ...    ...           ...             ...         ...           ...
# 7830  56.0     Perempuan       Freelance   Gorontalo  2.846557e+06
# 7831  31.0     Perempuan             PNS  Yogyakarta  5.187309e+06
# 7832  39.0     Laki-laki             PNS    Makassar  5.746771e+06
# 7833  35.0     Perempuan  Pegawai swasta     Kendari  1.087947e+07
# 7834  41.0     Perempuan             PNS  Yogyakarta  4.318450e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# 0              0           0.0  51.563794  158.490333  Shoulder & Head
# ...

# %% [markdown]
# #### Data Preprocessing [EDA]

# %%
dfB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7835 entries, 0 to 7834
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   umur           7835 non-null   float64
#  1   jenis_kelamin  7827 non-null   object
#  2   pekerjaan      7768 non-null   object
#  3   provinsi       7835 non-null   object
#  4   gaji           7835 non-null   float64
#  5   is_menikah     7835 non-null   int64
#  6   is_keturunan   7817 non-null   float64
#  7   berat          7835 non-null   float64
#  8   tinggi         7835 non-null   float64
#  9   sampo          7835 non-null   object
#  10  is_merokok     7835 non-null   int64
#  11  pendidikan     7835 non-null   object
#  12  botak_prob     7835 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 795.9+ KB

# %%
dfB.describe()
# Out:
#               umur          gaji   is_menikah  is_keturunan        berat  \
# count  7835.000000  7.835000e+03  7835.000000   7817.000000  7835.000000
# mean     39.463178  7.189956e+06     0.506701      0.203531    59.512621
# std       9.989158  3.393145e+06     0.499987      0.402650    11.676979
# min       4.000000  1.500000e+06     0.000000      0.000000    40.000000
# 25%      33.000000  4.868362e+06     0.000000      0.000000    51.450513
# 50%      40.000000  6.452511e+06     1.000000      0.000000    56.984565
# 75%      46.000000  8.598837e+06     1.000000      0.000000    64.613882
# max      75.000000  5.000000e+07     1.000000      1.000000   150.000000
#
#             tinggi   is_merokok   botak_prob
# count  7835.000000  7835.000000  7835.000000
# mean    158.839612     0.496745     0.439641
# std       7.268341     0.500021     0.194666
# min     131.412317     0.000000    -0.115039
# 25%     153.980168     0.000000     0.301574
# ...

# %%
dfB.isnull().sum()
# Out:
# umur              0
# jenis_kelamin     8
# pekerjaan        67
# provinsi          0
# gaji              0
# is_menikah        0
# is_keturunan     18
# berat             0
# tinggi            0
# sampo             0
# is_merokok        0
# pendidikan        0
# botak_prob        0
# dtype: int64

# %%
dfB['pekerjaan'].value_counts()
# Out:
# Pegawai swasta    3138
# PNS               3079
# Freelance         1235
# Pengangguran       316
# Name: pekerjaan, dtype: int64

# %%
dfB['is_keturunan'].value_counts()
# Out:
# 0.0    6226
# 1.0    1591
# Name: is_keturunan, dtype: int64

# %%
dfb = dfB[dfB['pekerjaan'].notnull()]
dfb
# Out:
#       umur jenis_kelamin       pekerjaan    provinsi          gaji  \
# 0     36.0     Laki-laki             PNS   Palembang  8.072967e+06
# 1     32.0     Perempuan       Freelance    Surabaya  6.632271e+06
# 2     35.0     Laki-laki             PNS        Palu  6.737048e+06
# 3     36.0     Laki-laki  Pegawai swasta   Samarinda  5.252883e+06
# 4     53.0     Laki-laki    Pengangguran       Ambon  8.279310e+06
# ...    ...           ...             ...         ...           ...
# 7830  56.0     Perempuan       Freelance   Gorontalo  2.846557e+06
# 7831  31.0     Perempuan             PNS  Yogyakarta  5.187309e+06
# 7832  39.0     Laki-laki             PNS    Makassar  5.746771e+06
# 7833  35.0     Perempuan  Pegawai swasta     Kendari  1.087947e+07
# 7834  41.0     Perempuan             PNS  Yogyakarta  4.318450e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# 0              0           0.0  51.563794  158.490333  Shoulder & Head
# ...

# %%
df_b = dfb[dfb['is_keturunan'].notnull()]
df_b
# Out:
#       umur jenis_kelamin       pekerjaan    provinsi          gaji  \
# 0     36.0     Laki-laki             PNS   Palembang  8.072967e+06
# 1     32.0     Perempuan       Freelance    Surabaya  6.632271e+06
# 2     35.0     Laki-laki             PNS        Palu  6.737048e+06
# 3     36.0     Laki-laki  Pegawai swasta   Samarinda  5.252883e+06
# 4     53.0     Laki-laki    Pengangguran       Ambon  8.279310e+06
# ...    ...           ...             ...         ...           ...
# 7830  56.0     Perempuan       Freelance   Gorontalo  2.846557e+06
# 7831  31.0     Perempuan             PNS  Yogyakarta  5.187309e+06
# 7832  39.0     Laki-laki             PNS    Makassar  5.746771e+06
# 7833  35.0     Perempuan  Pegawai swasta     Kendari  1.087947e+07
# 7834  41.0     Perempuan             PNS  Yogyakarta  4.318450e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# 0              0           0.0  51.563794  158.490333  Shoulder & Head
# ...

# %%
df = df_b[df_b['jenis_kelamin'].notnull()]
df
# Out:
#       umur jenis_kelamin       pekerjaan    provinsi          gaji  \
# 0     36.0     Laki-laki             PNS   Palembang  8.072967e+06
# 1     32.0     Perempuan       Freelance    Surabaya  6.632271e+06
# 2     35.0     Laki-laki             PNS        Palu  6.737048e+06
# 3     36.0     Laki-laki  Pegawai swasta   Samarinda  5.252883e+06
# 4     53.0     Laki-laki    Pengangguran       Ambon  8.279310e+06
# ...    ...           ...             ...         ...           ...
# 7830  56.0     Perempuan       Freelance   Gorontalo  2.846557e+06
# 7831  31.0     Perempuan             PNS  Yogyakarta  5.187309e+06
# 7832  39.0     Laki-laki             PNS    Makassar  5.746771e+06
# 7833  35.0     Perempuan  Pegawai swasta     Kendari  1.087947e+07
# 7834  41.0     Perempuan             PNS  Yogyakarta  4.318450e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# 0              0           0.0  51.563794  158.490333  Shoulder & Head
# ...

# %% [markdown]
# #### Visualisasi Data

# %%
#EDA melalui visualisasi data dari package dashboard 
import pywedge as pw
dashB = pw.Pywedge_Charts(df, c=None, y = 'botak_prob')
dashBoard = dashB.make_charts()
# Out:
# HTML(value='<h2>Pywedge Make_Charts </h2>')
# ...

# %% [markdown]
# ##### Insights Dashboard PyWedge:

# %% [markdown]
# SCATTER PLOT
# 1. Pada tampilan data Berat Vs Tinggi memiliki korelasi positif ditandai dengan variabel
#    'tinggi' yang semakin tinggi diikuti oleh nilai yang semakin tinggi dari variabel 'berat'
# 2. Pada tampilan data Gaji Vs Berat datanya mengumpul pada satu area yakni pada range Gaji
#    5M - 10M serta pada range Berat 45 - 60
# 3. Pada tampilan data Gaji Vs Umur dan Berat Vs Umur menunjukkan antar variabelnya memiliki
#    hubungan yang nonlinear
#
# PIE CHART
# 1. Perbandingan jumlah perokok antara Laki-laki dan perempuan pada tampilan Is_Merokok Vs
#    Jenis_Kelamin didominasi oleh laki-laki yakni 68.2%
# 2. Pada tampilan perbandingan data Is_Menikah Vs Pekerjaan besar persentase pekerja yang telah menikah didominasi
#    dari pegawai swasta yakni sebesar 40.2%
# 3. Pada tampilan perbandingan data Is_Merokok Vs Pekerjaan besar persentasi pekerja yang merokok didominasi oleh
#    pegawai swasta sebesar 39.9% dan PNS sebesar 39.1%
# 4. Pada tampilan perbandingan data Is_Menikah Vs Jenis_Kelamin individu yang telah menikah didominasi oleh
#    laki-laki yakni dengan persentase sebesar 71.3%
#
# BAR PLOT
# 1. Pada tampilan data Jenis_Kelamin Vs Is_Merokok terdapat dua kategori yakni perempuan dan laki-laki dimana
#    frekuensi perokok terbanyak adalah laki-laki
# 2. Pada tampilan data Pendidikan Vs Is_Merokok menggunakan kelas Jenis_Kelamin yang menunjukkan baik laki-laki
#    ataupun perempuan yang memiliki latar belakang pendidikan tinggi tetap memilih menjadi perokok bahkan memiliki
#    frekuensi paling tinggi dibandingkan kategori Pendidikan lainnya.
# 3. Pada tampilan data Pendidikan Vs Is_Menikah dengan kelas Jenis_Kelamin bahwa baik laki-laki ataupun perempuan
#    dengan latar belakang S1 yang telah menikah memiliki frekuensi paling tinggi dibandingkan kategori pendidikan
#    lainnya.
# 4. Pada tampilan data Pekerjaan Vs Is_Menikah dengan kelas Jenis_Kelamin menunjukkan bahwa individu laki-laki
#    PNS yang telah menikah memiliki frekuensi paling tinggi sedangkan individu perempuan pegawai swasta yang
#    telah menikah memiliki frekuensi paling tinggi
#
# VIOLIN PLOT
# 1. Kedua tampilan data yakni Is_Merokok Vs Is_Menikah dan Is_Merokok Vs Gaji memiliki kepadatan data yang kecil
#
# BOX PLOT
# 1. Keempat tampilan data box plot memiliki outliers
# 2. Pada tampilan data Pendidikan Vs Gaji, Pekerjaan Vs Gaji, dan Sampo Vs Gaji memiliki nilai minimum
#    yang hampir sama serta distribusi datanya memiliki jangkauan yang hampir sama pula.
# 3. Pada tampilan data Sampo Vs Umur dapat diketahui bahwa sampo baik pantone, merpati, shoulder&head,
#    deadbuoy, maupun moonsilk menyasar market dengan customer berumur 20 - 60 tahun atau termasuk kategori
#    umur dewasa.
#
# DISTRIBUTION PLOT
# 1. Pada tampilan data Umur Vs Is_Merokok diketahui bahwa umur perokok dengan frekuensi terbanyak yakni
#    berumur 34 - 35 pada provinsi bengkulu serta perokok berumur 46 - 47 pada provinsi padang
# 2. Pada tampilan data Gaji Vs Is_Merokok diketahui bahwa perokok laki-laki dengan frekuensi terbanyak
#    memiliki latar belakang pendapatan atau gaji sebesar 6 - 6,9
# 3. Pada tampilan data Umur Vs Berat diketahui bahwa pada range umur 36 - 42 laki-laki cenderung memiliki
#    massa badan yang lebih berat.
# 4. Pada tampilan data Tinggi Vs Berat diketahui bahwa individu yang memiliki tinggi 158 - 161 memiliki
#    massa badan yang lebih berat
#
# HISTOGRAM
# 1. Pada tampilan data umur dapat diketahui bahwa individu berumur 45 tahun memiliki frekuensi terbanyak
# 2. Pada tampilan data Gaji dapat diketahui bahwa nilai gaji dengan frekuensi terbanyak berada
#    pada jangkauan 4M - 5M
# 3. Pada tampilan data tinggi dapat diketahui bahwa jangkauan tinggi antara 156 - 157 memiliki frekuensi
#    terbanyak
# 4. Pada tampilan data berat dapat diketahui bahwa jangkauan berat antara 54 - 55 memiliki frekuensi
#    terbanyak
#
# CORRELATION
# 1. Pada tampilan correlation dapat disimpulkan bahwa perbandingan antar data numerikal tidak terdapat
#    korelasi atau hubungan yang ditandai dengan tidak adanya nilai pada data yang mendekati -1 atau 1.

# %%
#EDA melalui visualisasi data dari package dashboard 
# !pip3 install pandas_profiling --upgrade

# %%
import pandas_profiling as pp
from pandas_profiling import ProfileReport
pp.ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-03-28 13:17:19.981436&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ##### Insights Dashboard Pandas Profiling:

# %% [markdown]
# Beberapa Insight Penting yang Didapatkan yakni:
# 1. Rata-rata umur individu pada data yakni 39
# 2. Sebagian individu pada data berjenis kelamin laki-laki dengan besar persentase 66.9%
# 3. Sebagian besar individu pada data memiliki pekerjaan sebagai pegawai swasta dan PNS
# 4. Batas range gaji terendah keseluruhan individu pada data yakni sebesar 1.500.000 dan gaji tertingginya 50.000.000
# 5. Perbandingan persentase jumlah kelompok yang telah menikah ataupun belum menikah hanya memiliki selisih yang kecil yakni
#    50.7% yang telah menikah dan 49.3% yang belum menikah
# 6. Besar kelompok yang memiliki keturunan hanya sebesar 20.3% hal tersebut menunjukkan walaupun terdapat 50.7% kelompok yang
#    telah menikah belum semuanya memiliki keturunan
# 7. Besar rata-rata dari berat keseluruhan individu pada data yakni 59
# 8. Besar rata-rata dari tinggi keseluruhan individu pada data yakni 158
# 9. Data menunjukkan jumlah pengguna sampo baik pantone, merpati, shoulder&head, deadbuoy, maupun moonsilk hampir sama hanya
#    berkisar pada persentase 19.5% - 20.4%
# 10. Pada data sebagian jumlah individu dengan persentase 49.7% adalah perokok dan sebagian bukan perokok dengan persentase
#     50.3%
# 11. Latar belakang individu pada data didominasi oleh individu yang memiliki latar belakang S1
